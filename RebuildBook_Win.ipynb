# %%
import sys, os

# Resolve executables in *this* Python environment
scripts = os.path.join(os.path.dirname(sys.executable), "Scripts")
jbook = os.path.join(scripts, "jupyter-book.exe")
ghp = os.path.join(scripts, "ghp-import.exe")

print("Using jupyter-book at:", jbook)
print("Using ghp-import at:", ghp)

# 1. Clean previous build
# !rmdir /s /q book\_build

# 2. Build the book (book/ contains _config.yml + _toc.yml)
!"{jbook}" build book

# 3. Verify output
# !dir book\_build\html

# 4. Publish to gh-pages
!"{ghp}" -n -p -f book\_build\html
# Out:
# Using jupyter-book at: c:\Users\rober\anaconda3\envs\teaching_DSPN\Scripts\jupyter-book.exe
# Using ghp-import at: c:\Users\rober\anaconda3\envs\teaching_DSPN\Scripts\ghp-import.exe
# Running Jupyter-Book v1.0.4.post1
# Source Folder: c:\Users\rober\Dropbox\Professional\CarnegieMellon\Teaching\DataSciencePsychNeuro\GitHub_CourseNotebook\DSPN_CourseNotebook\book
# Config Path: c:\Users\rober\Dropbox\Professional\CarnegieMellon\Teaching\DataSciencePsychNeuro\GitHub_CourseNotebook\DSPN_CourseNotebook\book\_config.yml
# Output Path: c:\Users\rober\Dropbox\Professional\CarnegieMellon\Teaching\DataSciencePsychNeuro\GitHub_CourseNotebook\DSPN_CourseNotebook\book\_build\html
# Running Sphinx v7.4.7
# loading translations [en]... done
# making output directory... done
# [etoc] Changing master_doc to 'intro'
# ...
